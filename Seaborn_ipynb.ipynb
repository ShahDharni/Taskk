# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahDharni/Taskk/blob/main/Seaborn_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Seaborn**

# %% [markdown]
# **What is Seaborn ?**
#
# Seaborn provides a high-level interface to Matplotlib, a powerful but sometimes unwieldy Python visualization library.On Seaborn’s official website, they state:
#
# If matplotlib “tries to make easy things easy and hard things possible”, seaborn tries to make a well-defined set of hard things easy too.

# %% [markdown]
# **Features of Seaborn :**
#
# * Using default themes that are aesthetically pleasing.
#
# * Setting custom color palettes.
#
# * Making attractive statistical plots.
#
# * Easily and flexibly displaying distributions.
#
# * Visualizing information from matrices and DataFrames.
#
# Those last three points are why Seaborn is our tool of choice for Exploratory Analysis. It makes it very easy to “get to know” your data quickly and efficiently.

# %% [markdown]
# **Matplotlib Vs Seaborn**

# %% [markdown]
# It is summarized that if Matplotlib “tries to make easy things easy and hard things possible”, Seaborn tries to make a well-defined set of hard things easy too.”
#
# Seaborn helps resolve the two major problems faced by Matplotlib; the problems are −
#
# * Default Matplotlib parameters
#
# * Working with data frames
#
# As Seaborn compliments and extends Matplotlib, the learning curve is quite gradual. If you know Matplotlib, you are already half way through Seaborn.

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
d=pd.read_csv("Automobile_data.csv")
d.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# **Line Charts**

# %%
col1=np.linspace(0,10,100)
col2=np.sin(col1)
df=pd.DataFrame({"C1":col1,"C2":col2})
df.head(10)
# Out:
#          C1        C2
# 0  0.000000  0.000000
# 1  0.101010  0.100838
# 2  0.202020  0.200649
# 3  0.303030  0.298414
# 4  0.404040  0.393137
# 5  0.505051  0.483852
# 6  0.606061  0.569634
# 7  0.707071  0.649610
# 8  0.808081  0.722963
# 9  0.909091  0.788945

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-darkgrid')
# %matplotlib inline
sns.lineplot(x=df.C1,y=df.C2)
plt.show()

# %% [markdown]
# **Adjusting background color using axes.facecolor**
#
# **Changing labels using x.ticks and y.ticks**

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'black',
#  'patch.force_edgecolor': False,
#  'image.cmap': 'Greys',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'Liberation Sans',
#   'DejaVu Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
plt.style.use('seaborn-v0_8-darkgrid')
# %matplotlib inline
sns.set(rc={'axes.facecolor':'lightblue', 'axes.grid':True, 'xtick.labelsize':14,'ytick.labelsize':14})
sns.lineplot(x=df.C1,y=df.C2,data=df,linewidth=2.5)
sns.lineplot(x=df.C1,y=df.C2+1,data=df,linewidth=2.5)
plt.show()

# %%
plt.style.use('seaborn-v0_8-darkgrid')
# %matplotlib inline
sns.set(rc={'axes.facecolor':'lightblue', 'axes.grid':True, 'xtick.labelsize':14,'ytick.labelsize':14})
sns.lineplot(x=df.C1,y=df.C2,data=df,linewidth=2.5,color="green")
sns.lineplot(x=df.C1,y=np.cos(df.C2+1),data=df,linewidth=2.5,color="black")
plt.show()

# %% [markdown]
# **To recover the default matplotlib settings**

# %%
mpl.rcParams.update(mpl.rcParamsDefault)
# %matplotlib inline

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x="wheel-base",y="engine-size",data=d)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x="wheel-base",y="engine-size",data=d)
plt.title("Wheel_Base Vs Engine_Size")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x="wheel-base",y="engine-size",data=d,linewidth=5)
plt.title("Wheel_Base Vs Engine_Size")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=d['wheel-base'],linewidth=3, label="Wheel_Base")
sns.lineplot(data=d['engine-size'],linewidth=3, label="Engine-size")
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.set(rc={"axes.facecolor":"#283747","axes.grid":False,"xtick.labelsize":10,"ytick.labelsize":10})
plt.title("Engine size",fontsize=10)
plt.xticks(rotation=45)
sns.lineplot(x=d['wheel-base'],y=d['engine-size'].index.values,color="#ff9900")
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.style.use('seaborn-darkgrid')
sns.lineplot(x="wheel-base",y="engine-size",hue="fuel-type",data=d)
plt.show()
# Out:
# <ipython-input-81-2f192085607d>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
plt.figure(figsize=(10,4))
plt.style.use('seaborn-darkgrid')
sns.lineplot(x="wheel-base",y="engine-size", hue="fuel-type", data=d, markers=True, style="fuel-type")
plt.show()
# Out:
# <ipython-input-83-70528c0735b8>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
plt.figure(figsize=(14,7))
plt.style.use('seaborn-darkgrid')
sns.lineplot(x="num-of-cylinders", y="wheel-base", hue="fuel-type", data=d, markers=True, style="fuel-type",err_style="bars")
plt.show()
# Out:
# <ipython-input-47-fb6051cf2812>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
plt.figure(figsize=(14,7))
plt.style.use('seaborn-darkgrid')
sns.lineplot(x="num-of-cylinders", y="engine-size", hue="fuel-type",data=d)
sns.set(style="dark",)
plt.show()
# Out:
# <ipython-input-49-0684410e8891>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
plt.figure(figsize=(14,7))
sns.set(rc={'xtick.labelsize':14, "ytick.labelsize":10, "axes.labelsize":15})
sns.lineplot(x="wheel-base",y="engine-size", style="fuel-type", hue="fuel-type", dashes=False, palette = 'CMRmap', markers=["o", ">"] ,data=d)
plt.show()

# %%
plt.figure(figsize=(16,16))
plt.style.use("seaborn-darkgrid")
plt.gcf().text(.2,.70,"Line Plot",fontsize=35,color="blue",ha="center",va="center")
sns.lineplot(x="wheel-base",y="engine-size",hue="num-of-cylinders",style="fuel-type",data=d)
plt.show()
# Out:
# <ipython-input-85-8ee99dec0498>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-darkgrid")

# %% [markdown]
# **bbox_to_anchor**
#
# This means that any location of the legend we pass into the bbox_to_anchor= parameter will use the lower left as its bound. By passing in the tuple of (0, 1) , we tell Seaborn that we want the position to be bound to the far left (x = 0) of the graph, and at the top of the graph (y = 1).

# %%
plt.figure(figsize=(14,7))
plt.style.use('seaborn-v0_8-darkgrid')
sns.lineplot(x="engine-size",y="wheel-base", style="fuel-type",hue="num-of-cylinders",estimator=None,lw=1,units="num-of-cylinders",markers=True,dashes=False,data=d)
plt.legend(bbox_to_anchor=(1.0,1.0), fontsize="large",shadow=True)
plt.show()

# %% [markdown]
# **Seaborn Relplot**

# %% [markdown]
# **Relplot**: relplot in Seaborn allows us to visualise how variables within a dataset relate to each other
#
# Combining lineplots using relplot

# %%
plt.figure(figsize=(10,10))
sns.set(rc={'xtick.labelsize':17,'ytick.labelsize':17,'axes.grid':True,'axes.labelsize':20})
sns.relplot(x="engine-size",y="wheel-base",hue="num-of-cylinders", col="fuel-type",kind='line',style="fuel-type",data=d)
plt.show()

# %% [markdown]
# **Scatterplots**
#
# The most familiar way to visualize a bivariate distribution is a scatterplot, where each observation is shown with point at the x and y values. This is analgous to a rug plot on two dimensions. You can draw a scatterplot with the matplotlib plt.scatter function, and it is also the default kind of plot shown by the jointplot() function:

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x="engine-size",y="wheel-base",data=d,color="black")
plt.show()

# %% [markdown]
# Changing the shape of data points using "marker" parameter

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x="engine-size",y="wheel-base",data=d,color="black",marker="s")
plt.show()

# %% [markdown]
# Show groups with different colors using "hue"

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x="engine-size",y="wheel-base",data=d,color="black",marker="s",hue="fuel-type")
plt.show()

# %% [markdown]
# Setting X limit using "plt.xlim"

# %%
plt.figure(figsize=(10,10))
plt.xlim([50,200])
sns.scatterplot(x="engine-size",y="wheel-base",data=d,marker="s",hue="fuel-type")
plt.show()

# %% [markdown]
# Showing two different grouping variables using "hue" amd "style" parameter

# %%
plt.figure(figsize=(10,10))
plt.gcf().text(.5,.9,"Scatter Plot", fontsize=40, ha="center", va="center", color="black")
sns.scatterplot(x="wheel-base",y="engine-size",hue="num-of-cylinders",style="fuel-type",data=d)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x="wheel-base",y="engine-size",hue="fuel-type",size="city-mpg",sizes=(20,200),data=d)
plt.show()

# %% [markdown]
# Using the jointplot
#
# **Jointplot** : Draw a plot of two variables with bivariate and univariate graphs.
#
# Jointplot shows all possible combinations of columns present in the dataset.

# %%
sns.jointplot(x='wheel-base',y='engine-size',data=d,color="black")

# %% [markdown]
# **Relplot**

# %% [markdown]
# Relplot is used to plot the relation between two variables of a dataset on a graph(x-y axis) with semantic mappings of subset
#
# For example, there is a dataset with multiple variables such as age, height and gender. Let the x and y variables for the graph be age and height.

# %% [markdown]
# **Difference between Relplot and scatter plot**

# %% [markdown]
# relplot takes some of the same arguments as scatterplot , such as data, x, y , and hue , but adds other arguments as well.
#
# The major difference between relplot and scatterplot (as well as others) is that it can also segregate data attributes into rows and columns of subplots.

# %%
plt.figure(figsize=(14,17))
sns.relplot(x="engine-size",y="wheel-base",hue="fuel-type",kind="scatter",aspect=1,height=8.5,data=d)
plt.show()

# %%
plt.figure(figsize=(10,17))
sns.relplot(x="engine-size",y="wheel-base",hue="num-of-cylinders",data=d)
plt.show()

# %% [markdown]
# Use "Pallete" to specify the colors to be used for different levels of the hue

# %%
plt.figure(figsize=(10,7))
sns.set(rc={'xtick.labelsize':10,'ytick.labelsize':15,'axes.grid':True,'axes.labelsize':13})
sns.relplot(x="engine-size",y="wheel-base",hue="num-of-cylinders",kind="scatter",palette=["#FF3333" ,"#00CC00"],data=d, aspect=1,height=8.5)
plt.show()
# Out:
# <ipython-input-97-829e16293fc9>:3: UserWarning:
# The palette list has fewer values (2) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.relplot(x="engine-size",y="wheel-base",hue="num-of-cylinders",kind="scatter",palette=["#FF3333" ,"#00CC00"],data=d, aspect=1,height=8.5)

# %% [markdown]
# adding gcf

# %%
plt.figure(figsize=(14,16))
plt.style.use('seaborn-darkgrid')
sns.relplot(x="engine-size",y="wheel-base",hue="num-of-cylinders",kind="scatter",aspect=1,height=8.5,data=d)
plt.gcf().text(.5,.99,"Rel Plot",fontsize=40, color="black", ha="center", va="center")
plt.show()
# Out:
# <ipython-input-113-ec5e4d4945ea>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
#  Facet along the columns to show a categorical variable using "col" parameter

# %%
plt.figure(figsize=(14,20))
sns.set(rc={'xtick.labelsize':20,'ytick.labelsize':20,'axes.labelsize':20})
sns.relplot(x="engine-size",y="wheel-base",hue="fuel-type",kind='line', height= 8.5, aspect=1, data=d, col="num-of-cylinders")
plt.show()

# %% [markdown]
#  Facet along the columns and rows to show a categorical variable using "col" and "row" par

# %%
plt.figure(figsize=(14,20))
sns.set(rc={'xtick.labelsize':12,'ytick.labelsize':12,'axes.labelsize':12})
sns.relplot(x="engine-size",y="wheel-base",hue="fuel-type",kind='line', height= 8.5, aspect=1, data=d, col="num-of-cylinders",row="body-style")
plt.show()

# %% [markdown]
# Limiting the number of columns using "col_wrap"

# %%
sns.set(rc={'xtick.labelsize':12,'ytick.labelsize':12,'axes.labelsize':12})
sns.relplot(x="engine-size",y="wheel-base",hue="fuel-type",kind='line', height= 3, aspect=1, data=d, col="body-style",col_wrap=3)
plt.show()

# %% [markdown]
# **Bar Plot**

# %% [markdown]
# Bar Plot shows the relationship between a numerical variable and a categorical variable.
#
# A familiar style of plot that accomplishes this goal is a bar plot.
#
# In seaborn, the barplot() function operates on a full dataset and shows an arbitrary estimate, using the mean by default.
#
# When there are multiple observations in each category, it also uses bootstrapping to compute a confidence interval around the estimate and plots that using error bars:
#
# Bar plots include 0 in the quantitative axis range, and they are a good choice when 0 is a meaningful value for the quantitative variable, and you want to make comparisons against it.

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='body-style',y='city-mpg',data=d,palette="flare")
plt.show()

# %% [markdown]
# Sorted Bar Plot

# %%
plt.figure(figsize=(10,7))
order=d.groupby(['body-style']).mean().sort_values('city-mpg',ascending=False).index
order
sns.barplot(x="body-style", y="city-mpg", data=d, order=order)
plt.show()
# Out:
# <ipython-input-146-0b4000eabfb7>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   order=d.groupby(['body-style']).mean().sort_values('city-mpg',ascending=False).index

# %% [markdown]
# **Horizontal Bar Plot**

# %%
plt.figure(figsize=(7,10))
sns.barplot(x='city-mpg',y='body-style', data=d, orient="h")
plt.show()

# %% [markdown]
# **Count Plot**

# %% [markdown]
# Show the counts of observations in each categorical bin using bars
#
# A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable.
#
# countplot() method is used to show the counts of observations in each categorical bin using bars.

# %%
plt.figure(figsize=(10,7))
sns.countplot(x="body-style",data=d)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.countplot(x="body-style", order=d['body-style'].value_counts().index,data=d)
plt.show()

# %% [markdown]
# Changing the background of bar plot

# %%
plt.figure(figsize=(10,7))
sns.set(rc={'axes.facecolor': "#283747","axes.grid":False,"xtick.labelsize":20,"ytick.labelsize":20})
sns.countplot(x="body-style", order=d['body-style'].value_counts().index,data=d)
plt.show()

# %%
mpl.rcParams.update(mpl.rcParamsDefault)
# %matplotlib inline

# %% [markdown]
# Adding hue

# %%
plt.figure(figsize=(10,7))
sns.barplot(x="body-style", y="city-mpg",hue=d['fuel-type'],data=d)
plt.show()

# %% [markdown]
# **Cat Plot**

# %% [markdown]
# Cat Plot provides access to several axes-level functions ("point", "bar", "strip", "swarm","box", "violin", "count" or "boxen") that show the relationship between a numerical and one or more categorical variables

# %% [markdown]
# Use Count Plot to visualize *data*

# %%
plt.figure(figsize=(10,7))
sns.catplot(y="body-style", data=d, kind="count")
plt.show()

# %% [markdown]
# Use sorted  Count Plot to visualize data

# %%
plt.figure(figsize=(10,7))
sns.catplot(y="body-style", data=d, order=d['body-style'].value_counts().index, kind="count")
plt.show()

# %% [markdown]
#  Use Voilin Plot to visualize data

# %%
plt.figure(figsize=(12,10))
sns.catplot(x="body-style",y="city-mpg", kind="violin",data=d)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.catplot(x="body-style",y="city-mpg", kind="violin",data=d,height=4,aspect=1)
plt.show()

# %% [markdown]
# Facet along the columns to show a categorical variable using "col" parameter

# %%
plt.figure(figsize=(10,10))
sns.catplot(x="body-style",y="city-mpg",col="fuel-type",data=d)
plt.show()

# %% [markdown]
#  Facet along the columns to show a categorical variable using "col" parameter and
#
# Limiting the number of columns using "col_wrap"

# %%
plt.figure(figsize=(20,10))
sns.catplot(x="fuel-type", col="body-style",col_wrap=2,kind="count",height=5, aspect=1,data=d)
plt.show()

# %% [markdown]
# **Dist Plot**

# %% [markdown]
# It is used basically for univariant set of observations and visualizes it through a histogram i.e. only one observation and hence we choose one particular column of the dataset.

# %% [markdown]
# **Why do we use dist plot ?**

# %% [markdown]
# We use a displot (also known as a distribution plot) to represent data in histogram form. It is a univariant set of collected data, which means the data distribution of one variable will be shown against another variable.

# %% [markdown]
# The most convenient way to take a quick look at a univariate distribution in seaborn is the distplot() function. By default, this will draw a histogram and fit a kernel density estimate (KDE).

# %%
plt.figure(figsize=(10,10))
sns.distplot(d["engine-size"])
plt.show()
# Out:
# <ipython-input-213-a90118047589>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d["engine-size"])

# %% [markdown]
# **Histograms**

# %% [markdown]
# Histograms are likely familiar, and a hist function already exists in matplotlib. A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.
#
# To illustrate this, let’s remove the density curve and add a rug plot, which draws a small vertical tick at each observation. You can make the rug plot itself with the rugplot() function, but it is also available in distplot():

# %%
plt.figure(figsize=(10,10))
sns.distplot(d["city-mpg"],kde=False,rug=True) ## Rug and KDE are plots in distplot
plt.show()
# Out:
# <ipython-input-216-e64977fa0f04>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d["city-mpg"],kde=False,rug=True) ## Rug and KDE are plots in distplot

# %% [markdown]
# Histogram with rugplot and kde

# %%
plt.figure(figsize=(10,10))
sns.distplot(d['city-mpg'],rug=True,kde=True,hist=False)
plt.show()
# Out:
# <ipython-input-219-2142c32b1b78>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['city-mpg'],rug=True,kde=True,hist=False)

# %%
d.hist(bins=40,figsize=(20,20))
plt.show()

# %%
plt.figure(figsize=(11,7))
sns.distplot(d['city-mpg'],bins=20)
plt.show()
# Out:
# <ipython-input-221-dd931f904959>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['city-mpg'],bins=20)

# %%
plt.figure(figsize=(11,7))
sns.distplot(d['city-mpg'],bins=20,hist_kws=dict(edgecolor = '#FF0000'))
plt.show()
# Out:
# <ipython-input-228-cd69a50deda3>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['city-mpg'],bins=20,hist_kws=dict(edgecolor = '#FF0000'))

# %% [markdown]
# **KDE plot**

# %% [markdown]
# KDE Plot is used to estimate the probability density function of a continuous random variable.
#
# Kernel Density Estimation (KDE) is a way to estimate the probability density function of a continuous random variable.

# %%
sns.set_style("darkgrid")
fig1,axes=plt.subplots(nrows=2,ncols=2,figsize=(14,14))
x=np.random.normal(1,10,1000)
# Simple KDE plot
axes[0,0].set_title("Simple KDE Plot")
sns.kdeplot(x,ax=axes[0,0])
# Shade under the density curve using the "shade" parameter
axes[0,1].set_title("KDE Plot (shaded area under the curve)")
sns.kdeplot(x,ax=axes[0,1],shade=True)
# Shade under the density curve using the "shade" parameter and use a different color.
axes[1,0].set_title("Different color shade)")
sns.kdeplot(x,ax=axes[1,0],shade=True,color="r",cut=0)
#Plotting the density on the vertical axis
axes[1,1].set_title("Plotting on vertical axis)")
sns.kdeplot(x,vertical=True)
plt.show()
# Out:
# <ipython-input-233-b5d4cdc0ca9b>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x,ax=axes[0,1],shade=True)
# <ipython-input-233-b5d4cdc0ca9b>:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x,ax=axes[1,0],shade=True,color="r",cut=0)
# <ipython-input-233-b5d4cdc0ca9b>:15: UserWarning:
#
# The `vertical` parameter is deprecated; assigning data to `y`.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   sns.kdeplot(x,vertical=True)

# %%
plt.figure(figsize=(6,8))
x = np.linspace(0, 10, 100)
y = np.sin(x)
sns.kdeplot(x=x,y=y,shade=True,cmap="Reds", shade_lowest=False)
# Out:
# <ipython-input-256-c89f2912e884>:4: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   sns.kdeplot(x=x,y=y,shade=True,cmap="Reds", shade_lowest=False)
# <ipython-input-256-c89f2912e884>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=x,y=y,shade=True,cmap="Reds", shade_lowest=False)
# <Axes: >

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(x="city-mpg",y="engine-size",shade=True,cmap="Reds", thresh=False,data=d)
plt.show()
# Out:
# <ipython-input-263-64c616cdeab4>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x="city-mpg",y="engine-size",shade=True,cmap="Reds", thresh=False,data=d)

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(x="engine-size",y="wheel-base",cmap="Reds",shade=True,shade_lowest=False,data=d)
plt.show()
# Out:
# <ipython-input-268-43e7eff523d8>:2: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   sns.kdeplot(x="engine-size",y="wheel-base",cmap="Reds",shade=True,shade_lowest=False,data=d)
# <ipython-input-268-43e7eff523d8>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x="engine-size",y="wheel-base",cmap="Reds",shade=True,shade_lowest=False,data=d)

# %% [markdown]
# **Swarm Plot**

# %% [markdown]
# Swarmplot() method is used to draw a non-overlapping scatter plot where one of the variables is a categorical variable.
#
# Swarmplot, which is used to visualize categorical data with numerical values

# %% [markdown]
# Simple Swarm plot

# %%
plt.figure(figsize=(10,10))
sns.swarmplot(x="fuel-type",y='city-mpg',data=d)
plt.show()

# %% [markdown]
# Draw horizontal swarm plot

# %%
plt.figure(figsize=(10,10))
sns.swarmplot(x="fuel-type",y='city-mpg',data=d,orient="h")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 76.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 88.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 62.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# Defining the size of the plots

# %%
plt.figure(figsize=(10,7))
sns.swarmplot(x="fuel-type",y="city-mpg",data=d,size=10)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 7.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Displaying multiple swarmplots using subplot function.

# %%
fig,axes=plt.subplots(nrows=2,ncols=2,figsize=(10,10))
sns.swarmplot(x="fuel-type",y="city-mpg",ax=axes[0,0],size=8,data=d)
sns.swarmplot(x="fuel-type",y="wheel-base",ax=axes[0,1],size=8,data=d)
sns.swarmplot(x="fuel-type",y="length",ax=axes[1,0],size=8,data=d)
sns.swarmplot(x="fuel-type",y="length",ax=axes[1,1],size=8,data=d)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 16.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 15.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
